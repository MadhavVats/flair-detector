# %%
import praw
import pandas as pd

# %%
reddit = praw.Reddit(client_id='MwhK0qtk4ZqRdw', client_secret='cjytrTxD1OR4KtmEyZRk6wY7tfI', user_agent='flair' ,username='gcgvhjchvt2244')
flairs_list = ["AskIndia", "Non-Political", "[R]eddiquette", "Scheduled", "Photography", "Science/Technology", "Politics", "Business/Finance", "Policy/Economy", "Sports", "Food", "AMA"]
subreddit = reddit.subreddit('india')
topics_dict = {"flairs":[], "titles":[], "upvotes":[], "id":[], "url":[], "num_comms": [], "created": [], "content":[], "op":[], "comments":[]}
for template in subreddit.flair.templates:
    print(template)
# for flair in flairs_list:
#     post = subreddit.search(flair, limit=100)
# Out:
# ------------------------------------------------
# APIException   Traceback (most recent call last)
# <ipython-input-18-9bcca4ffa1b1> in <module>
#       3 subreddit = reddit.subreddit('india')
#       4 topics_dict = {"flairs":[], "titles":[], "upvotes":[], "id":[], "url":[], "num_comms": [], "created": [], "content":[], "op":[], "comments":[]}
# ----> 5 for template in subreddit.flair.templates:
#       6     print(template)
#       7 # for flair in flairs_list:
#
# ~/.local/lib/python3.7/site-packages/praw/models/reddit/subreddit.py in __iter__(self)
#    1377         url = API_PATH["user_flair"].format(subreddit=self.subreddit)
#    1378         params = {"unique": self.subreddit._reddit._next_unique}
# -> 1379         for template in self.subreddit._reddit.get(url, params=params):
#    1380             yield template
#    1381
#
# ~/.local/lib/python3.7/site-packages/praw/reddit.py in get(self, path, params)
#     441         """
#     442         data = self.request("GET", path, params=params)
# --> 443         return self._objector.objectify(data)
#     444
#     445     def info(self, fullnames=None, url=None):
#
# ~/.local/lib/python3.7/site-packages/praw/objector.py in objectify(self, data)
#     156             errors = data["json"]["errors"]
#     157             if len(errors) == 1:
# --> 158                 raise APIException(*errors[0])
#     159             assert not errors
#     160         elif isinstance(data, dict):
#
# APIException: USER_REQUIRED: 'Please log in to do that.'
